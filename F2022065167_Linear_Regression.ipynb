# %%
import numpy as np

# %%
class Linear_Regression:
    def __init__(self):
        pass

    def fit(self):
        pass

    def update_weights(self):
        pass

    def predict(self):
        pass

# %%
class Linear_Regression():
    def __init__(self, ):
        pass

    def fit(self, ):
        pass

    def update_weights(self, ):
        pass

    def predict(self, ):
        pass

# %%
class Linear_Regression():
    def __init__(self, ):
        pass

    def fit(self, ):
        pass

    def update_weights(self, ):
        pass

    def predict(self, ):
        pass

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

model = Linear_Regression()

# %%
import numpy as np



class Linear_Regression():


    def _init_(self, learning_rate, no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, ):
        pass

    def update_weights(self, ):
        pass

    def predict(self, ):
        pas

# %%
class Linear_Regression():


    def _init_(self, learning_rate, no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, X, Y):
        self.m, self.n = X.shape

    def update_weights(self, ):
        pass

    def predict(self, ):
        pass

# %%
def _init_(self, learning_rate, no_of_iterations):
    self.learning_rate = learning_rate
    self.no_of_iterations = no_of_iterations

def fit(self, X, Y):

    self.m, self.n = X.shape


    self.w = np.zeros(self.n)
    self.b = 0
    self.X = X
    self.Y = Y

def update_weights(self):
    pass

def predict(self):
    pass

# %%
def fit(self, X, Y):

    self.m, self.n = X.shape


    self.w = np.zeros(self.n)
    self.b = 0
    self.X = X
    self.Y = Y

    for i in range(self.no_of_iterations):
        self.update_weights()

def update_weights(self):
    pass

def predict(self):
    pass

# %%
def fit(self, X, Y):

    self.m, self.n = X.shape


    self.w = np.zeros(self.n)
    self.b = 0
    self.X = X
    self.Y = Y

    for i in range(self.no_of_iterations):
        self.update_weights()

def update_weights(self):
    Y_predicting = self.predict(self.X)

def predict(self, X):
    return X.dot(self.w) + self.b

# %%
class Linear_Regression():


    def __init__(self, learning_rate, no_of_iterations):
        self.learning_rate = learning_rate
        self.no_of_iterations = no_of_iterations

    def fit(self, X, Y):
        self.m, self.n = X.shape

        self.w = np.zeros(self.n)
        self.b = 0
        self.X = X
        self.Y = Y

        for i in range(self.no_of_iterations):
            self.update_weights()

    def update_weights(self):
        Y_predicting = self.predict(self.X)

        dw=-2*(self.X.T).dot(self.Y-Y_predicting)
        db=-2*np.sum(self.Y-Y_predicting)

    def predict(self, X):
        return X.dot(self.w) + self.b

# %%
    def update_weights(self):
        Y_predicting = self.predict(self.X)

        dw=-2*(self.X.T).dot(self.Y-Y_predicting)
        db=-2*np.sum(self.Y-Y_predicting)

        self.w = self.w - self.learning_rate*dw
        self.b = self.b - self.learning_rate*db

    def predict(self, X):
        return X.dot(self.w) + self.b

# %%
 def predict(self, X):
        return X.dot(self.w) + self.b

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
import pandas as pd
salary_data = pd.read_csv('/content/salary_data.csv')

# %%
salary_data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
salary_data.tail()
# Out:
#     YearsExperience  Salary
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
salary_data.shape
# Out:
# (30, 2)

# %%
salary_data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=salary_data.iloc[:,:-1].values
y=salary_data.iloc[:,-1].values

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=2)

# %%
print(y)
# Out:
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression(learning_rate=0.02, no_of_iterations=1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-5e6711a891fc> in <cell line: 3>()
#       1 from sklearn.linear_model import LinearRegression
#       2
# ----> 3 model = LinearRegression(learning_rate=0.02, no_of_iterations=1000)
#
# TypeError: LinearRegression.__init__() got an unexpected keyword argument 'learning_rate'

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print('weight =', model.w[0])
print('bias =', model.b)
# Out:
# weight = 2.0
# bias = 0.0

# %%
test_data_prediction = model.predict(x_test)

# %%
print(test_data_prediction)
# Out:
# [ 2.6  2.2  9.   7.4 14.2 12. ]

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test, y_test, color='red')
plt.plot(x_test, test_data_prediction, color='blue')
plt.title('Salary_vs_Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
